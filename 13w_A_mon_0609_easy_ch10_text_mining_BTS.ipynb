# %% [markdown]
# <a href="https://colab.research.google.com/github/ai7dnn/2025-1-BDA/blob/main/inclass/13w_A_mon_0609_easy_ch10_text_mining_BTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 13주 BTS 댓글 워드 클라우드

# %%
# !pip install koreanize-matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (0.1.1)
# Requirement already satisfied: matplotlib in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from koreanize-matplotlib) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from matplotlib->koreanize-matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from matplotlib->koreanize-matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from matplotlib->koreanize-matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from matplotlib->koreanize-matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from matplotlib->koreanize-matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from matplotlib->koreanize-matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from matplotlib->koreanize-matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)

# %%
import koreanize_matplotlib

# %%
FONT_PATH = '/usr/local/lib/python3.11/dist-packages/koreanize_matplotlib/fonts/NanumGothic.ttf'

# %%
# !pip show wordcloud
# Out:
# Name: wordcloud
# Version: 1.9.4
# Summary: A little word cloud generator
# Home-page: https://github.com/amueller/word_cloud
# Author:
# Author-email: Andreas Mueller <t3kcit+wordcloud@gmail.com>
# License: MIT License
# Location: /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages
# Requires: matplotlib, numpy, pillow
# Required-by:

# %%
# !pip show konlpy
# Out:
# Name: konlpy
# Version: 0.6.0
# Summary: Python package for Korean natural language processing.
# Home-page: http://konlpy.org
# Author: Team KoNLPy
# Author-email: konlpy@googlegroups.com
# License: GPL v3
# Location: /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages
# Requires: JPype1, lxml, numpy
# Required-by:

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from konlpy) (1.5.2)
# Requirement already satisfied: lxml>=4.1.0 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from konlpy) (5.4.0)
# Requirement already satisfied: numpy>=1.6 in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages (from JPype1>=0.7.0->konlpy) (25.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %%
df = pd.read_csv('data/news_comment_BTS.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   reg_time  1200 non-null   object
#  1   reply     1200 non-null   object
#  2   press     1200 non-null   object
#  3   title     1200 non-null   object
#  4   url       1200 non-null   object
# dtypes: object(5)
# memory usage: 47.0+ KB

# %%
df.sample(5)
# Out:
#                  reg_time                                              reply  \
# 143   2020-09-01 06:35:23                                        대단하고 자랑스럽네요
# 762   2020-09-01 03:18:19  대단한거도 인정이고 국위선양도 ㅆ인정인데 여기서 군면제 얘기가 왜나오냐 OOO들아 ...
# 1069  2020-09-01 02:56:14                                      개미쳤네 싸이도2위한건데
# 958   2020-09-01 03:02:43                                정말 눈물난다 너무 축하해ㅠㅜㅜㅜㅜ
# 892   2020-09-01 03:06:29                         그동안 고생했네 방탄소년단ㆍ아미ㆍ빅히트 축하축하
#
#      press                                        title  \
# 143   한국경제        [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 762   경향신문  BTS, 한국 가수 최초 미 빌보드 싱글차트 1위···‘다이너마이트’급 대기록
# 1069  경향신문  BTS, 한국 가수 최초 미 빌보드 싱글차트 1위···‘다이너마이트’급 대기록
# 958   경향신문  BTS, 한국 가수 최초 미 빌보드 싱글차트 1위···‘다이너마이트’급 대기록
# 892   경향신문  BTS, 한국 가수 최초 미 빌보드 싱글차트 1위···‘다이너마이트’급 대기록
#
#                                                     url
# 143   https://news.naver.com/main/read.nhn?mode=LSD&...
# 762   https://news.naver.com/main/read.nhn?mode=LSD&...
# 1069  https://news.naver.com/main/read.nhn?mode=LSD&...
# 958   https://news.naver.com/main/read.nhn?mode=LSD&...
# 892   https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
df.reply[:10] # df라는 데이터프레임에서 "reply" 열을 가져오고, 그 열의 앞에서부터 10개만 추출하겠다는 뜻이에요!
# Out:
# 0                                    국보소년단<U+0001F49C>
# 1                                         아줌마가 들어도 좋더라
# 2    팩트체크\n\n현재 빌보드 HOT 100\n\n1위  방탄소년단[BTS]\n2위 C...
# 3              방탄소년단이 한국사람이라 너무 자랑스러워요 ㅠㅠ 우리오래오래 함께하자!
# 4                  대단한 BTS, 월드 클래스는 다르네^^ 좋은 소식!! 응원해요
# 5                        정국오빠 생일과 더불어 빌보드 1위기사라니ㅠㅠ축제구나
# 6    정말 축하하고 응원하지만\n집에서 여러 계정으로 스트리밍 돌리고 사재기하고 다른 팬...
# 7                         기자는 자고 일어났지만, 팬들은 못자고 발표 기다림
# 8                                자랑스럽다!!!!!! 축하합니다!!!!
# 9                                 SuperM 늘 응원하고 사랑합니다~
# Name: reply, dtype: object

# %%
df['reply'].str.replace('[^가-힣]', ' ', regex = True)

# "reply" 열 안에 있는 문자 중에서
# 한글이 아닌 건 다 공백(' ')으로 바꿔라!
# Out:
# 0                                       국보소년단
# 1                                            아줌마가 들어도 좋더라
# 2       팩트체크  현재 빌보드           위  방탄소년단       위       ...
# 3                 방탄소년단이 한국사람이라 너무 자랑스러워요    우리오래오래 함께하자
# 4                     대단한      월드 클래스는 다르네   좋은 소식   응원해요
#                               ...
# 1195                                       역시
# 1196    우리 탄이들 너무 자랑스럽고 사랑해                           ...
# 1197                               이런애들 꼭 군대를 보내 는게  맞을까요
# 1198                                            군면제급이다 이건
# 1199    자랑스러워요 정말   축하해 김남준 김석진 민윤기 정호석 박지민 김태형 전정국   ...
# Name: reply, Length: 1200, dtype: object

# %%
df['reply'] = df['reply'].str.replace('[^가-힣]', ' ', regex = True)
df['reply'].sample(5)
# Out:
# 33             가진 것 하나 없던 시절에서 이제는 세계 정상    영화보다도 영화같다
# 967                                           야  기분 딱 좋다
# 1069                                        개미쳤네 싸이도 위한건데
# 749     방탄소년단 대단하네   봉준호의 오스카 관왕에 이어 빌보드 핫     위면 대한민국...
# 78                                         초록뱀 주가 오르게 생겼네
# Name: reply, dtype: object

# %%
from konlpy.tag import Hannanum
han = Hannanum()
han.nouns(u'질문이나 건의사항은 깃헙 이슈 트레커에 남겨주세요.')
# Out:
# WARNING: A restricted method in java.lang.System has been called
# WARNING: java.lang.System::load has been called by org.jpype.JPypeContext in an unnamed module (file:/opt/miniconda3/envs/VDLP/lib/python3.11/site-packages/org.jpype.jar)
# WARNING: Use --enable-native-access=ALL-UNNAMED to avoid a warning for callers in this module
# WARNING: Restricted methods will be blocked in a future release unless native access is enabled
# ['질문', '건의사항', '깃헙', '이슈', '트레커']

# %%
from konlpy.tag import Kkma
kkma = Kkma()
kkma.nouns(u'질문이나 건의사항은 깃헙 이슈 트레커에 남겨주세요.')

# Kkma는 더 많이 나온다! Hannanum 보다!
# Out:
# ['질문', '건의', '건의사항', '사항', '깃헙', '이슈', '트레커']

# %%
mydf = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
mydf
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dfs = mydf.apply(lambda x: x**2)
dfs
# Out:
#    A   B
# 0  1  16
# 1  4  25
# 2  9  36

# %%
mydf.apply(lambda x: x + 2)
# Out:
#    A  B
# 0  3  6
# 1  4  7
# 2  5  8

# %%
df['reply'].sample(5)
# Out:
# 113                              축하해요      너무 자랑스럽네요
# 299     미스 미스터 트롯도 좋아하지만  방탄소년단  정치에실망한국민께 큰힘을주네요   응원...
# 110     정말 축하합니다 자랑스러운 한국가수     보이밴드중 역사상  번째로 빌보드 핫  ...
# 1124                     스포츠 스타보딘 낫다  국위선양 공으로 군 면제  좋아요
# 508     진짜 이정도면 군면제해야하는거아님   금메달리스트들보다도 한국을 더 알리고잇고 국위...
# Name: reply, dtype: object

# %%
nouns = df['reply'].apply(kkma.nouns)
nouns
# Out:
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
#
# java.lang.NullPointerException: Cannot invoke "java.util.List.size()" because "melAnalResult" is null
# 	at org.snu.ids.ha.ma.MorphemeAnalyzer.postProcess(MorphemeAnalyzer.java:258)
# 	at org.snu.ids.ha.index.KeywordExtractor.extractKeyword(KeywordExtractor.java:127)
# 	at kr.lucypark.kkma.KkmaInterface.extractNoun(Unknown Source)
# 0                                        [국보, 국보소년단, 소년단]
# 1                                                   [아줌마]
# 2                   [팩트, 팩트체크, 체크, 보드, 위, 방탄, 방탄소년단, 소년단]
# 3              [방탄, 방탄소년단, 소년단, 한국, 한국사람, 사람, 자랑, 우리, 하자]
# 4                                       [월드, 클래스, 소식, 응원]
#                               ...
# 1195                                                   []
# 1196                                      [우리, 탄, 자랑, 사랑]
# 1197                                              [애, 군대]
# 1198                                     [군, 군면제급, 면제, 급]
# 1199    [자랑, 축하, 김, 김남, 남, 김석진, 민, 민윤기, 윤기, 정, 정호석, 호석...
# Name: reply, Length: 1200, dtype: object

# %%
nouns = nouns.explode()
nouns
# Out:
# 0          국보
# 0       국보소년단
# 0         소년단
# 1         아줌마
# 2          팩트
#         ...
# 1199      박지민
# 1199      김태형
# 1199        전
# 1199      전정국
# 1199       정국
# Name: reply, Length: 9353, dtype: object

# %%
test = pd.DataFrame({'A': [[1, 2, 3], 'foo', [], [3, 4]], 'B': 1,
                     'C': [['a', 'b', 'c'], np.nan, [], ['d', 'e']]})
test
# Out:
#            A  B          C
# 0  [1, 2, 3]  1  [a, b, c]
# 1        foo  1        NaN
# 2         []  1         []
# 3     [3, 4]  1     [d, e]

# %%
test.explode('A') # 기말 시험 예상
# explode()는 리스트 항목이 없을 경우,"펼칠 요소가 없으니 그냥 NaN으로 처리"하기 때문이야.
# Out:
#      A  B          C
# 0    1  1  [a, b, c]
# 0    2  1  [a, b, c]
# 0    3  1  [a, b, c]
# 1  foo  1        NaN
# 2  NaN  1         []
# 3    3  1     [d, e]
# 3    4  1     [d, e]

# %%
test
# Out:
#            A  B          C
# 0  [1, 2, 3]  1  [a, b, c]
# 1        foo  1        NaN
# 2         []  1         []
# 3     [3, 4]  1     [d, e]

# %%
test.explode(['A', 'C']) # 기말 시험 예상
# Out:
#      A  B    C
# 0    1  1    a
# 0    2  1    b
# 0    3  1    c
# 1  foo  1  NaN
# 2  NaN  1  NaN
# 3    3  1    d
# 3    4  1    e

# %%
test.explode(['A', 'C']) # 기말 시험 예상

# test.explode(['A', 'C']) 와 같이 2개를 explode 할때 개수가 서로 맞지 않으면 오류발생!
# Out:
#      A  B    C
# 0    1  1    a
# 0    2  1    b
# 0    3  1    c
# 1  foo  1  NaN
# 2  NaN  1  NaN
# 3    3  1    d
# 3    4  1    e

# %%
df_word = pd.DataFrame({'word': nouns})
df_word.sample(5)
# Out:
#     word
# 469   가수
# 475   지금
# 921  소년단
# 574   밴드
# 214   메달

# %%
df_word['len'] = df_word['word'].str.len()
df_word = df_word.query('len >= 2')
df_word.sample(5)
# Out:
#      word  len
# 495   올림픽  3.0
# 1137   역사  2.0
# 27    위라니  3.0
# 1187   시국  2.0
# 722    영광  2.0

# %%
df_word.query('word == "소년단"')
# Out:
#      word  len
# 0     소년단  3.0
# 2     소년단  3.0
# 3     소년단  3.0
# 27    소년단  3.0
# 29    소년단  3.0
# ...   ...  ...
# 1123  소년단  3.0
# 1159  소년단  3.0
# 1162  소년단  3.0
# 1164  소년단  3.0
# 1176  소년단  3.0
#
# [144 rows x 2 columns]

# %%
df_word = df_word.groupby('word', as_index=False) \
                 .agg(n = ('word', 'count')) \
                 .sort_values('n', ascending=False)
df_word
# Out:
#        word    n
# 752      방탄  280
# 1878     축하  236
# 1556     자랑  205
# 1032    소년단  144
# 763   방탄소년단  136
# ...     ...  ...
# 1136   실력있음    1
# 406    다음주면    1
# 1134     신화    1
# 1133     신중    1
# 1084    스을적    1
#
# [2168 rows x 2 columns]

# %%
top20 = df_word.head(20)
top20
# Out:
#        word    n
# 752      방탄  280
# 1878     축하  236
# 1556     자랑  205
# 1032    소년단  144
# 763   방탄소년단  136
# 813      보드  131
# 618      면제  125
# 233     군면제   78
# 225      군대   77
# 1364     우리   68
# 11       가수   64
# 987      선양   62
# 215    국위선양   59
# 214      국위   58
# 328      나라   53
# 2038     한국   52
# 371      노래   50
# 463    대한민국   46
# 708      민국   46
# 462      대한   46

# %%
plt.figure(figsize=(6, 4))
sns.barplot(data=top20, y='word', x='n', hue='word');

# %%
from PIL import Image
icon = Image.open('data/cloud.png')

img = Image.new('RGB', icon.size, (255, 255, 255))
img.paste(icon, icon)

img = np.array(img)
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
df_word.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2168 entries, 752 to 1084
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   word    2168 non-null   object
#  1   n       2168 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 50.8+ KB

# %%
df_word.sample(5)
# Out:
#      word  n
# 751    방영  1
# 1916  케이팝  8
# 525    래요  2
# 1660   정체  1
# 1574   자체  4

# %%
dic_word = df_word.set_index('word').to_dict()['n'] # 'n'은 df_word 안에 있는 열(column)의 이름이에요.
dic_word
# Out:
# {'방탄': 280,
#  '축하': 236,
#  '자랑': 205,
#  '소년단': 144,
#  '방탄소년단': 136,
#  '보드': 131,
#  '면제': 125,
#  '군면제': 78,
#  '군대': 77,
#  '우리': 68,
#  '가수': 64,
#  '선양': 62,
#  '국위선양': 59,
#  '국위': 58,
#  '나라': 53,
#  '한국': 52,
#  '노래': 50,
#  '대한민국': 46,
#  '민국': 46,
#  '대한': 46,
#  '진짜': 43,
#  '최고': 40,
#  '대박': 39,
#  '세계': 36,
#  '아미': 35,
#  '소식': 31,
#  '시기': 30,
#  '생각': 30,
#  '정국': 29,
#  '사람': 29,
#  '라니': 29,
#  '행복': 29,
#  '사랑': 28,
#  '역사': 28,
#  '생일': 27,
#  '코로나': 27,
#  '차트': 27,
#  '핫백': 26,
#  '위라니': 24,
#  '감사': 24,
#  '축하해': 23,
#  '우리나라': 23,
#  '전세계': 22,
#  '그룹': 22,
#  '싱글': 22,
#  '미국': 22,
#  '이것': 22,
#  '진심': 22,
#  '인정': 22,
#  '정도': 22,
#  '노력': 21,
#  '응원': 20,
#  '요즘': 19,
#  '음악': 19,
#  '활동': 19,
#  '고생': 18,
#  '최초': 17,
#  '아이': 17,
#  '너희': 15,
#  '국가': 15,
#  '올림픽': 15,
#  '이제': 15,
#  '문화': 15,
#  '때문': 15,
#  '국민': 15,
#  '뉴스': 15,
#  '기분': 14,
#  '숟가락': 14,
#  '기사': 14,
#  '멤버': 14,
#  '수고': 14,
#  '대통령': 14,
#  '내가': 14,
#  '한국인': 13,
#  '아티스트': 13,
#  '눈물': 13,
#  '이름': 13,
#  '시국': 13,
#  '마이트': 12,
#  '금메달': 12,
#  '지금': 12,
#  '아시아': 12,
#  '댓글': 12,
#  '친구': 11,
#  '위로': 11,
#  '재인': 11,
#  '남자': 11,
#  '싱글차트': 11,
#  '국뽕': 11,
#  '기록': 11,
#  '국내': 10,
#  '대표': 10,
#  '하나': 10,
#  '시대': 10,
#  '다이': 10,
#  '선물': 10,
#  '병역': 10,
#  '마라': 10,
#  '사상': 10,
#  '문재인': 10,
#  '이번': 9,
#  '역사상': 9,
#  '하루': 9,
#  '그것': 9,
#  '재앙': 9,
#  '만큼': 9,
#  '진정': 9,
#  '희망': 9,
#  '하다': 9,
#  '인기': 9,
#  '얘기': 9,
#  '케이': 9,
#  '가사': 8,
#  '오늘': 8,
#  '세계적': 8,
#  '위상': 8,
#  '의미': 8,
#  '청와대': 8,
#  '정상': 8,
#  '계속': 8,
#  '동안': 8,
#  '덕분': 8,
#  '하자': 8,
#  '콩쿨': 8,
#  '케이팝': 8,
#  '경사': 8,
#  '아이돌': 8,
#  '데뷔': 8,
#  '애국': 8,
#  '시절': 8,
#  '홍보': 8,
#  '소름': 7,
#  '월드컵': 7,
#  '보이': 7,
#  '정치': 7,
#  '단하': 7,
#  '감격': 7,
#  '앨범': 7,
#  '의무': 7,
#  '한번': 7,
#  '얘들': 7,
#  '다이너마이트': 7,
#  '여기': 7,
#  '일본': 7,
#  '실력': 7,
#  '한국가수': 7,
#  '이상': 7,
#  '영향력': 7,
#  '자리': 7,
#  '효과': 7,
#  '경제': 7,
#  '독도': 6,
#  '아침': 6,
#  '순위': 6,
#  '건강': 6,
#  '거지': 6,
#  '아들': 6,
#  '밴드': 6,
#  '다음': 6,
#  '세금': 6,
#  '하면': 6,
#  '블랙': 6,
#  '이젠': 6,
#  '기간': 6,
#  '결국': 6,
#  '사이': 6,
#  '영광': 6,
#  '처음': 6,
#  '수가': 6,
#  '영어': 6,
#  '멜론': 6,
#  '동시대': 6,
#  '누구': 6,
#  '외국': 6,
#  '외교': 6,
#  '가치': 6,
#  '모두': 6,
#  '우울': 6,
#  '마음': 6,
#  '월드': 6,
#  '쾌거': 6,
#  '대중': 5,
#  '스타': 5,
#  '보유국': 5,
#  '대상': 5,
#  '시간': 5,
#  '성장': 5,
#  '군대면': 5,
#  '순간': 5,
#  '나이': 5,
#  '시민': 5,
#  '시작': 5,
#  '여자': 5,
#  '여러분': 5,
#  '영원': 5,
#  '업적': 5,
#  '와우': 5,
#  '완전': 5,
#  '메달': 5,
#  '기생충': 5,
#  '애국자': 5,
#  '기쁨': 5,
#  '기부': 5,
#  '역사적': 5,
#  '도움': 5,
#  '니들': 5,
#  '아무': 5,
#  '이거': 5,
#  '그래미': 5,
#  '속보': 5,
#  '기자': 5,
#  '트롯': 5,
#  '개월': 5,
#  '추카': 5,
#  '국격': 5,
#  '존경': 5,
#  '필요': 5,
#  '발표': 5,
#  '가요': 5,
#  '훈련': 5,
#  '국가대표': 5,
#  '무엇': 5,
#  '메인': 5,
#  '경제적': 5,
#  '주세': 5,
#  '거기': 5,
#  '진입': 5,
#  '레전': 5,
#  '축하축하': 5,
#  '문제': 5,
#  '해외': 5,
#  '결과': 5,
#  '청년': 5,
#  '히트': 5,
#  '기대': 4,
#  '한글': 4,
#  '영국': 4,
#  '꽃길': 4,
#  '새벽': 4,
#  '방시혁': 4,
#  '방시': 4,
#  '챠트': 4,
#  '유명': 4,
#  '존재': 4,
#  '비교': 4,
#  '무대': 4,
#  '비틀즈': 4,
#  '실화': 4,
#  '중요': 4,
#  '주자': 4,
#  '문재앙': 4,
#  '기회': 4,
#  '투표': 4,
#  '기초': 4,
#  '마지막': 4,
#  '문통': 4,
#  '문씨': 4,
#  '팬덤': 4,
#  '예술': 4,
#  '영화': 4,
#  '주라': 4,
#  '발매': 4,
#  '모습': 4,
#  '나의': 4,
#  '인생': 4,
#  '해라': 4,
#  '국방': 4,
#  '이후': 4,
#  '경제효과': 4,
#  '병역면제': 4,
#  '추카추카': 4,
#  '가슴': 4,
#  '축구': 4,
#  '세상': 4,
#  '군대면제': 4,
#  '내가수': 4,
#  '혜택': 4,
#  '재능': 4,
#  '성과': 4,
#  '대체': 4,
#  '국제': 4,
#  '사회': 4,
#  '자기': 4,
#  '자체': 4,
#  '힐링': 4,
#  '군사': 4,
#  '손실': 4,
#  '정부': 4,
#  '그대': 4,
#  '나중': 4,
#  '감동': 4,
#  '가지': 4,
#  '얘네들': 4,
#  '초청': 4,
#  '이래': 4,
#  '번째': 4,
#  '선수': 4,
#  '이용': 4,
#  '이유': 4,
#  '카디비': 3,
#  '아저씨': 3,
#  '년만': 3,
#  '얘네': 3,
#  '언론': 3,
#  '넘사벽': 3,
#  '코로나때문': 3,
#  '상상': 3,
#  '안해': 3,
#  '게임': 3,
#  '큰일': 3,
#  '어디': 3,
#  '걱정': 3,
#  '애국시민': 3,
#  '데뷔때': 3,
#  '튜브': 3,
#  '특별': 3,
#  '승승장구': 3,
#  '스포츠': 3,
#  '스타일': 3,
#  '해주자': 3,
#  '간만': 3,
#  '수십': 3,
#  '현실': 3,
#  '가요계': 3,
#  '대회': 3,
#  '가야': 3,
#  '성공': 3,
#  '휴가': 3,
#  '대중가요': 3,
#  '대형': 3,
#  '가도': 3,
#  '성적': 3,
#  '가능': 3,
#  '강경': 3,
#  '한국어': 3,
#  '시상식': 3,
#  '삼성': 3,
#  '아시아인': 3,
#  '생활': 3,
#  '느낌': 3,
#  '파이': 3,
#  '파이팅': 3,
#  '쓰럽': 3,
#  '표현': 3,
#  '핑크': 3,
#  '강남스타일': 3,
#  '다이나': 3,
#  '다이나마이트': 3,
#  '하루종일': 3,
#  '다행': 3,
#  '신곡': 3,
#  '하세': 3,
#  '시장': 3,
#  '겹경사': 3,
#  '보드차트': 3,
#  '얼굴': 3,
#  '블랙핑크': 3,
#  '기초군사훈련': 3,
#  '라디오': 3,
#  '이도': 3,
#  '적폐': 3,
#  '공연': 3,
#  '빅히트': 3,
#  '우승': 3,
#  '보이밴드': 3,
#  '인간적': 3,
#  '복무': 3,
#  '주면': 3,
#  '군인': 3,
#  '종일': 3,
#  '방법': 3,
#  '외화': 3,
#  '병무청': 3,
#  '미국인': 3,
#  '관왕': 3,
#  '디피씨': 3,
#  '본인': 3,
#  '유일': 3,
#  '유튜브': 3,
#  '국가적': 3,
#  '딴것': 3,
#  '그동안': 3,
#  '정신': 3,
#  '의사': 3,
#  '리스트': 3,
#  '쟤들': 3,
#  '요새': 3,
#  '준호': 3,
#  '보답': 3,
#  '미스': 3,
#  '막내': 3,
#  '최소': 3,
#  '최근': 3,
#  '역할': 3,
#  '국익': 3,
#  '청춘': 3,
#  '입대': 3,
#  '사벽': 3,
#  '보드핫백': 3,
#  '참고': 3,
#  '완벽': 3,
#  '영어권': 3,
#  '사고': 3,
#  '찬성': 3,
#  '오랜만': 3,
#  '국방부': 3,
#  '보이그룹': 3,
#  '지네': 3,
#  '오빠': 3,
#  '예전': 3,
#  '보고': 3,
#  '정권': 3,
#  '국보': 3,
#  '옛날': 3,
#  '국회': 3,
#  '병역특례': 2,
#  '명곡': 2,
#  '메세지': 2,
#  '설명': 2,
#  '벌이': 2,
#  '벤치': 2,
#  '보드싱글': 2,
#  '봉준호': 2,
#  '모든': 2,
#  '모름': 2,
#  '보물': 2,
#  '본고장': 2,
#  '부탁': 2,
#  '버스': 2,
#  '생일날': 2,
#  '빈국': 2,
#  '생일축하': 2,
#  '바래요': 2,
#  '사건': 2,
#  '문죄인': 2,
#  '생일선물': 2,
#  '문화적': 2,
#  '박수': 2,
#  '바다': 2,
#  '뮤비': 2,
#  '믹스': 2,
#  '뮤지션': 2,
#  '보드핫': 2,
#  '상승': 2,
#  '바리': 2,
#  '문대통령': 2,
#  '부담': 2,
#  '무능': 2,
#  '선배': 2,
#  '백만': 2,
#  '목적': 2,
#  '방포': 2,
#  '부족': 2,
#  '방탄주': 2,
#  '부존자원': 2,
#  '선구자': 2,
#  '방탄보유국': 2,
#  '방탄때문': 2,
#  '비티에스': 2,
#  '빅뱅': 2,
#  '반대': 2,
#  '반감': 2,
#  '미스터': 2,
#  '가게': 2,
#  '세계문화': 2,
#  '주고': 2,
#  '제목': 2,
#  '제일': 2,
#  '조금': 2,
#  '조선': 2,
#  '죄인': 2,
#  '주가': 2,
#  '주모': 2,
#  '세계인': 2,
#  '주변': 2,
#  '주시': 2,
#  '주신': 2,
#  '주의': 2,
#  '증명': 2,
#  '지도': 2,
#  '제대': 2,
#  '정치적': 2,
#  '정치인': 2,
#  '정치얘기': 2,
#  '정작': 2,
#  '정의': 2,
#  '정수기': 2,
#  '정말': 2,
#  '정국이도': 2,
#  '젊은이': 2,
#  '전정국': 2,
#  '전원': 2,
#  '전역': 2,
#  '전부': 2,
#  '전드': 2,
#  '전달': 2,
#  '전국민': 2,
#  '지붕': 2,
#  '지원': 2,
#  '철수': 2,
#  '평생': 2,
#  '훈장': 2,
#  '훈련소': 2,
#  '후보': 2,
#  '획득': 2,
#  '홍보대사': 2,
#  '행사': 2,
#  '행보': 2,
#  '해주고': 2,
#  '해용': 2,
#  '한명': 2,
#  '한남': 2,
#  '하지': 2,
#  '피땀': 2,
#  '포방포': 2,
#  '팩트': 2,
#  '초대': 2,
#  '파급': 2,
#  '파구': 2,
#  '특례': 2,
#  '테러': 2,
#  '텃세': 2,
#  '탄주': 2,
#  '키즈': 2,
#  '클래식': 2,
#  '콘서트': 2,
#  '컴백': 2,
#  '칭찬': 2,
#  '취향': 2,
#  '축하해용': 2,
#  '축제': 2,
#  '재능기부': 2,
#  '잘못': 2,
#  '작년': 2,
#  '아이디': 2,
#  '연예인': 2,
#  '연기': 2,
#  '역대': 2,
#  '여건': 2,
#  '엑스': 2,
#  '에스': 2,
#  '언플': 2,
#  '억정': 2,
#  '어이': 2,
#  '암울': 2,
#  '안티': 2,
#  '안보': 2,
#  '안됨': 2,
#  '악플러들': 2,
#  '아시안': 2,
#  '영상': 2,
#  '아시아가수': 2,
#  '아빠': 2,
#  '아니쥬': 2,
#  '쓰럽게': 2,
#  '실시간': 2,
#  '신경': 2,
#  '시고': 2,
#  '스트리밍': 2,
#  '수식어': 2,
#  '수상': 2,
#  '손흥민': 2,
#  '소통': 2,
#  '소년': 2,
#  '소개': 2,
#  '열광': 2,
#  '영웅': 2,
#  '자원': 2,
#  '이의': 2,
#  '자신': 2,
#  '자부심': 2,
#  '자랑쓰런': 2,
#  '일위': 2,
#  '일본인': 2,
#  '인지도': 2,
#  '인재': 2,
#  '인성': 2,
#  '인사': 2,
#  '인물': 2,
#  '인권': 2,
#  '인간': 2,
#  '이해': 2,
#  '이정': 2,
#  '이랑': 2,
#  '오랫만': 2,
#  '의원': 2,
#  '음원': 2,
#  '음악적': 2,
#  '유럽': 2,
#  '윈윈': 2,
#  '위치': 2,
#  '위버스': 2,
#  '위기': 2,
#  '월드스타': 2,
#  '워드': 2,
#  '운동선수': 2,
#  '운동': 2,
#  '우리나라가수': 2,
#  '외화벌이': 2,
#  '메달딴것': 2,
#  '힘내': 2,
#  '그때': 2,
#  '기적': 2,
#  '다운': 2,
#  '감사해': 2,
#  '동급': 2,
#  '겸손': 2,
#  '돌이': 2,
#  '갱신': 2,
#  '구도': 2,
#  '넘버원': 2,
#  '당신': 2,
#  '리얼': 2,
#  '리스펙': 2,
#  '리스': 2,
#  '김석진': 2,
#  '독보적': 2,
#  '과거': 2,
#  '그네': 2,
#  '네이버': 2,
#  '공익': 2,
#  '고장': 2,
#  '고통': 2,
#  '기획사': 2,
#  '거리': 2,
#  '그래미상': 2,
#  '만이': 2,
#  '도로': 2,
#  '고민': 2,
#  '교육': 2,
#  '꼰대': 2,
#  '마이클잭': 2,
#  '국제콩쿨': 2,
#  '경제적가치': 2,
#  '관련주': 2,
#  '마세': 2,
#  '경제적효과': 2,
#  '등극': 2,
#  '드로': 2,
#  '개인적': 2,
#  '강제': 2,
#  '난리': 2,
#  '마이클': 2,
#  '단군': 2,
#  '경비대': 2,
#  '단군이래': 2,
#  '나스': 2,
#  '단비': 2,
#  '관광객': 2,
#  '강남': 2,
#  '광고': 2,
#  '나무': 2,
#  '개판': 2,
#  '국적': 2,
#  '끝물': 2,
#  '마니': 2,
#  '덤핑': 2,
#  '개인': 2,
#  '말자': 2,
#  '공감': 2,
#  '기간동안': 2,
#  '년전': 2,
#  '근무': 2,
#  '기본적': 2,
#  '머리카락': 2,
#  '레전드로': 2,
#  '대사': 2,
#  '국보급': 2,
#  '머리': 2,
#  '레전드': 2,
#  '대신': 2,
#  '래요': 2,
#  '라도': 2,
#  '가보': 2,
#  '글로벌': 2,
#  '격과': 2,
#  '곳곳': 2,
#  '누구도': 2,
#  '기자분': 2,
#  '기여': 2,
#  '기업': 2,
#  '능가': 2,
#  '공부': 2,
#  '국개의원': 2,
#  '디피': 2,
#  '멋지네': 2,
#  '국가홍보': 2,
#  '기억': 2,
#  '가수라니': 2,
#  '대중성': 2,
#  '로드': 2,
#  '국격과': 2,
#  '국가차원': 1,
#  '광고효과': 1,
#  '국가적인': 1,
#  '정체': 1,
#  '전세계최대시장': 1,
#  '정치외교': 1,
#  '정찰': 1,
#  '점심': 1,
#  '전성기': 1,
#  '관심을': 1,
#  '관심': 1,
#  '정치충': 1,
#  '정의당': 1,
#  '정호석': 1,
#  '전설': 1,
#  '제가': 1,
#  '제국': 1,
#  '관리법': 1,
#  '전생': 1,
#  '전멤버': 1,
#  '광팬': 1,
#  '전원군면제': 1,
#  '교가': 1,
#  '정은경': 1,
#  '정도로': 1,
#  '절대': 1,
#  '구봉': 1,
#  '구속': 1,
#  '정국이의': 1,
#  '구장': 1,
#  '제대자': 1,
#  '정국오빠': 1,
#  '절반': 1,
#  '젊은얘들': 1,
#  '정국군': 1,
#  '구한': 1,
#  '구한테': 1,
#  '정구기': 1,
#  '정구': 1,
#  '정도일': 1,
#  '구리': 1,
#  '정밀': 1,
#  '전쟁': 1,
#  '전용기': 1,
#  '정은': 1,
#  '국가위상': 1,
#  '교육후': 1,
#  '점수': 1,
#  '전자': 1,
#  '국가대표급': 1,
#  '전함': 1,
#  '정상적': 1,
#  '전체': 1,
#  '구기': 1,
#  '정부관계자': 1,
#  '전파': 1,
#  '정복': 1,
#  '멍충이': 1,
#  '조종': 1,
#  '제어': 1,
#  '공정': 1,
#  '중년': 1,
#  '중국': 1,
#  '줄아시': 1,
#  '줄세우': 1,
#  '줄기': 1,
#  '공백기': 1,
#  '주훈련': 1,
#  '주지': 1,
#  '주죠': 1,
#  '주정': 1,
#  '주작': 1,
#  '주임': 1,
#  '주일': 1,
#  '공사': 1,
#  '주요뉴스': 1,
#  '주요': 1,
#  '주심': 1,
#  '공사기업': 1,
#  '공수': 1,
#  '중단': 1,
#  '중독성': 1,
#  '중반': 1,
#  '즈그땅': 1,
#  '지대': 1,
#  '공급': 1,
#  '공긍횡령': 1,
#  '지구': 1,
#  '지경': 1,
#  '지가': 1,
#  '공로': 1,
#  '증거': 1,
#  '즈그들': 1,
#  '중복': 1,
#  '중학교': 1,
#  '중장년': 1,
#  '중요성': 1,
#  '공백': 1,
#  '중앙일보': 1,
#  '중앙': 1,
#  '중소기업': 1,
#  '중복투표': 1,
#  '공인': 1,
#  '공직자': 1,
#  '제외': 1,
#  '주말': 1,
#  '조회수': 1,
#  '조회': 1,
#  '조현병': 1,
#  '조현': 1,
#  '조차': 1,
#  '조짐중': 1,
#  '조짐': 1,
#  '조직적': 1,
#  '국내대회': 1,
#  '조작': 1,
#  '조원': 1,
#  '조심': 1,
#  '조단위더': 1,
#  '조단': 1,
#  '조나스': 1,
#  '관광업': 1,
#  '조건': 1,
#  '제일영웅': 1,
#  '관련': 1,
#  '조회수로': 1,
#  '관광': 1,
#  '관계자': 1,
#  '과언': 1,
#  '주만': 1,
#  '주류': 1,
#  '주둥이': 1,
#  '주도': 1,
#  '주길': 1,
#  '주구장창': 1,
#  '과반수': 1,
#  '주간': 1,
#  '과일': 1,
#  '존재자체': 1,
#  '좌파': 1,
#  '좌절': 1,
#  '좌익': 1,
#  '좋가': 1,
#  '과한': 1,
#  '종례시간': 1,
#  '종례': 1,
#  '졸개': 1,
#  '국경': 1,
#  '장관': 1,
#  '적인': 1,
#  '이만치': 1,
#  '굿굿': 1,
#  '이바지': 1,
#  '이미지': 1,
#  '이문덕': 1,
#  '이문': 1,
#  '이명박이': 1,
#  '이명': 1,
#  '이면': 1,
#  '이만큼': 1,
#  '이름때문': 1,
#  '이거엄청': 1,
#  '그거': 1,
#  '이루': 1,
#  '이때': 1,
#  '이득': 1,
#  '그래미가면': 1,
#  '이대': 1,
#  '이놈': 1,
#  '이네': 1,
#  '이기세가': 1,
#  '이빨': 1,
#  '굴욕외교': 1,
#  '이성': 1,
#  '이요': 1,
#  '인기확보': 1,
#  '군면제사유': 1,
#  '군면제찬성': 1,
#  '인건': 1,
#  '군면제해라': 1,
#  '군복': 1,
#  '군복무': 1,
#  '이행': 1,
#  '군복무대신': 1,
#  '이쯤': 1,
#  '군사법원': 1,
#  '군입대': 1,
#  '군제대자': 1,
#  '이전': 1,
#  '이자': 1,
#  '군필': 1,
#  '군필자': 1,
#  '이용촬영': 1,
#  '굴욕': 1,
#  '이기': 1,
#  '그레': 1,
#  '인마': 1,
#  '유사이래': 1,
#  '윤미향': 1,
#  '윤기': 1,
#  '육군': 1,
#  '유행': 1,
#  '극한': 1,
#  '유툽': 1,
#  '유일한': 1,
#  '유일하다': 1,
#  '근래': 1,
#  '유사': 1,
#  '이가': 1,
#  '유발': 1,
#  '유명하다': 1,
#  '유도': 1,
#  '유닛': 1,
#  '유니폼': 1,
#  '유능': 1,
#  '금년': 1,
#  '위해': 1,
#  '금메달급': 1,
#  '융성': 1,
#  '으헝': 1,
#  '으헝헝헝': 1,
#  '음모': 1,
#  '그레미': 1,
#  '의식': 1,
#  '그룹뿐': 1,
#  '의민지': 1,
#  '그룹임': 1,
#  '의무적': 1,
#  '그룹차트': 1,
#  '그릇': 1,
#  '음활동': 1,
#  '그중': 1,
#  '음악활동': 1,
#  '음악캠프': 1,
#  '그해': 1,
#  '음악역사': 1,
#  '음악성': 1,
#  '음악계': 1,
#  '음악가': 1,
#  '극찬': 1,
#  '음방': 1,
#  '인데': 1,
#  '군면제급': 1,
#  '적극': 1,
#  '자제': 1,
#  '잘만': 1,
#  '작품': 1,
#  '작성': 1,
#  '국보소년단': 1,
#  '작곡과': 1,
#  '작곡가': 1,
#  '국봉': 1,
#  '자존감': 1,
#  '자존': 1,
#  '자유': 1,
#  '국악대회': 1,
#  '국뽕소년단': 1,
#  '자연': 1,
#  '국뽕차': 1,
#  '자식': 1,
#  '자세': 1,
#  '국수': 1,
#  '자만': 1,
#  '국악': 1,
#  '자로': 1,
#  '잘뽑앗더라': 1,
#  '지도자': 1,
#  '장관아들': 1,
#  '장난': 1,
#  '저희': 1,
#  '저질': 1,
#  '저번': 1,
#  '저기': 1,
#  '국대': 1,
#  '쟤네들': 1,
#  '쟤네': 1,
#  '쟝르': 1,
#  '재판대기중': 1,
#  '재판': 1,
#  '국문학': 1,
#  '국민청원': 1,
#  '재수': 1,
#  '재벌기업': 1,
#  '재벌': 1,
#  '국민투표': 1,
#  '국방의무': 1,
#  '장르': 1,
#  '장년': 1,
#  '자랑쓰럽': 1,
#  '자랑스럽군': 1,
#  '군대얘기': 1,
#  '인트': 1,
#  '일본도': 1,
#  '일보': 1,
#  '일베충': 1,
#  '일루미': 1,
#  '일루': 1,
#  '일등': 1,
#  '일곱': 1,
#  '일가': 1,
#  '인트로': 1,
#  '인터넷공급': 1,
#  '자랑럽': 1,
#  '인터넷': 1,
#  '국회의원': 1,
#  '인증': 1,
#  '인정이다': 1,
#  '군대가지마라': 1,
#  ...}

# %%
wc = WordCloud(random_state=1234, font_path=FONT_PATH,
               width = 400, height = 400, background_color='white',
               mask = img)

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
imgWC = wc.generate_from_frequencies(dic_word)
plt.figure(figsize=(6, 4));
plt.axis('off')
plt.imshow(imgWC);
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 imgWC = wc.generate_from_frequencies(dic_word)
#       2 plt.figure(figsize=(6, 4));
#       3 plt.axis('off')
#
# File /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages/wordcloud/wordcloud.py:453, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     451     font_size = self.height
#     452 else:
# --> 453     self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                    max_font_size=self.height)
#     455     # find font sizes
#     456     sizes = [x[1] for x in self.layout_]
#
# File /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages/wordcloud/wordcloud.py:506, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     504     break
#     505 # try to find a position
# --> 506 font = ImageFont.truetype(self.font_path, font_size)
#     507 # transpose font optionally
#     508 transposed_font = ImageFont.TransposedFont(
#     509     font, orientation=orientation)
#
# File /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages/PIL/ImageFont.py:880, in truetype(font, size, index, encoding, layout_engine)
#     877     return FreeTypeFont(font, size, index, encoding, layout_engine)
#     879 try:
# --> 880     return freetype(font)
#     881 except OSError:
#     882     if not is_path(font):
#
# File /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages/PIL/ImageFont.py:877, in truetype.<locals>.freetype(font)
#     876 def freetype(font: StrOrBytesPath | BinaryIO) -> FreeTypeFont:
# --> 877     return FreeTypeFont(font, size, index, encoding, layout_engine)
#
# File /opt/miniconda3/envs/VDLP/lib/python3.11/site-packages/PIL/ImageFont.py:285, in FreeTypeFont.__init__(self, font, size, index, encoding, layout_engine)
#     283                 load_from_bytes(f)
#     284             return
# --> 285     self.font = core.getfont(
#     286         font, size, index, encoding, layout_engine=layout_engine
#     287     )
#     288 else:
#     289     load_from_bytes(cast(IO[bytes], font))
#
# OSError: cannot open resource

# %% [markdown]
# # 기말고사 예상

# %%
import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [10, 20, 30]
})
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
# 각 열의 최대값에서 최소값을 뺀 결과
print(df.apply(lambda x: x.max() - x.min(), axis=0))
# Out:
# A     2
# B    20
# dtype: int64

# %%
# 각 열의 최대값에서 최소값을 뺀 결과
print(df.apply(lambda x: x.max() - x.min()))
# Out:
# A     2
# B    20
# dtype: int64

# %%
# 각 열의 최대값에서 최소값을 뺀 결과
print(df.apply(lambda x: x.max() - x.min(), axis=1))
# Out:
# 0     9
# 1    18
# 2    27
# dtype: int64

# %%
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
f = lambda x: x + 5
df.apply(f)
# Out:
#    A   B
# 0  6  15
# 1  7  25
# 2  8  35

# %%
f = lambda x: x * 5
df.apply(f, axis=1)
# Out:
#     A    B
# 0   5   50
# 1  10  100
# 2  15  150

# %%
f = lambda x: x / 5
df.apply(f, axis=1)
# Out:
#      A    B
# 0  0.2  2.0
# 1  0.4  4.0
# 2  0.6  6.0

# %%
# 각 행의 평균 구하기
print(df.apply(lambda x: x.mean(), axis=1))
# Out:
# 0     5.5
# 1    11.0
# 2    16.5
# dtype: float64

# %%
# 각 열의 평균 구하기
print(df.apply(lambda x: x.mean(), axis=0))
# Out:
# A     2.0
# B    20.0
# dtype: float64

# %%
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df.apply(lambda x: x.sum(), axis=0)
# Out:
# A     6
# B    60
# dtype: int64

# %%
df.apply(sum, axis=0)
# Out:
# A     6
# B    60
# dtype: int64

# %%
df.apply(sum, axis=1)
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
df.sum(axis=0)
# Out:
# A     6
# B    60
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Alice', 'Bob'],
    'hobbies': [['reading', 'cooking'], ['gaming']]
})
df
# Out:
#     name             hobbies
# 0  Alice  [reading, cooking]
# 1    Bob            [gaming]

# %%
# explode 적용
df_exploded = df.explode('hobbies')
df_exploded
# Out:
#     name  hobbies
# 0  Alice  reading
# 0  Alice  cooking
# 1    Bob   gaming

# %%
from IPython.display import display_html
def display_side_by_side(*args):
    """여러 데이터프레임 비교가 쉽게 옆쪽으로 표시한다"""
    html_str=''
    for df in args:
        html_str += df.to_html() + '&nbsp;'*4
    display_html(html_str.replace('table','table style="display:inline"'), raw=True)

# %%
# 여러 열을 동시에 explode (Pandas 1.3.0 이상)
df = pd.DataFrame({
    'A': [[1, 2], [3]],
    'B': [['a', 'b'], ['c']]
})
df
# Out:
#         A       B
# 0  [1, 2]  [a, b]
# 1     [3]     [c]

# %%
display_side_by_side(df, df.explode(['A']))
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[1, 2]</td>
#       <td>[a, b]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[3]</td>
#       <td>[c]</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>[a, b]</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>[a, b]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>[c]</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %%
display_side_by_side(df, df.explode(['B']))
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[1, 2]</td>
#       <td>[a, b]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[3]</td>
#       <td>[c]</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[1, 2]</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>[1, 2]</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[3]</td>
#       <td>c</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %%
display_side_by_side(df, df.explode(['A', 'B']))
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[1, 2]</td>
#       <td>[a, b]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[3]</td>
#       <td>[c]</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>c</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %% [markdown]
# ## 종료
